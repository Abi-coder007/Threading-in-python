# %%
import threading

# %%
def task():
    print("Thread is running")

t1 = threading.Thread(target=task)

t1.start()
# Out:
# Thread is running

# %%
def task():
    print("arrshik")
t2 = threading.Thread(target=task)

t2.start()
# Out:
# arrshik

# %%
def tree():
    print("grow a tree")
t = threading.Thread(target=tree)

t.start()
# Out:
# grow a tree

# %%
def add():
    print(220+220)

def sub():
    print(1234-451)

t1 = threading.Thread(target=add)
t2 = threading.Thread(target=sub)

t1.start()
t2.start()
# Out:
# 440
# 783
